# %% [markdown]
# name: shahad altamimi

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise 1
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
# Solution goes here

from jupyturtle import make_turtle, forward, left


def rectangle(w, h):
    for i in range(2):
        forward(w)
        left(90)
        forward(h)
        left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 230,75 230,35 150,35 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
#  ### Exercise 2
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
# Solution goes here
from jupyturtle import make_turtle, forward, left, right
def rhombus(side, angle):
    for i in range(2):
        forward(side)
        left(angle)
        forward(side)
        left(180 - angle)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75 200,75 225,31.7 175,31.7 150,75" />'
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exerciseg 3
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
# Solution goes here
def parallelogram(length, width, angle):
    forward(length)
    left(180 - angle)
    forward(width)
    left(angle)
    forward(length)
    left(180 - angle)
    forward(width)
    left(angle)

# %%
# Solution goes here
def rectangle(length, width):
    parallelogram(length, width, 90)

# %%
# Solution goes here
def rhombus(length, angle):
    parallelogram(length, length, angle)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(width=400)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="400" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 200,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 80,75 160,75 160,35 80,35 80,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 180,75 230,75 205,31.7 155,31.7 180,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 260,75 340,75 315,31.7 235,31.7 260,75" />'
#
# <g transform="rotate(-90.0,260.0,75.0) translate(260.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise 4
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
# Solution goes here
def triangle(length, angle):
    forward(length)
    left(180 - angle)
    forward(length)
    left(180 - angle)
    forward(length)
    left(180 - angle)

# %%
# Solution goes here
def draw_pie(n, length):
    angle = 360 / n
    
    for i in range(n):
        triangle(length, angle)
        left(angle)

# %%
def jump(length):
    penup()
    forward(length)
    pendown()

# %% [markdown]
# You can use the following code to test your functions.

# %%
from jupyturtle import *

turtle = make_turtle(delay=0)

jump(80)

size = 40

draw_pie(5, size)
jump(2*size)

draw_pie(6, size)
jump(2*size)

draw_pie(7, size)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 230,75 270,75 257.6,37 225.3,60.5 257.6,37 225.3,13.4 212.9,51.5 225.3,13.4 185.3,13.4 197.6,51.5 185.3,13.4 152.9,37 185.3,60.5 152.9,37 140.6,75 180.6,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 100.6,75 60.6,75 80.6,109.6 100.6,75 80.6,109.6 120.6,109.6 100.6,75 120.6,109.6 140.6,75 100.6,75 140.6,75 120.6,40.4 100.6,75 120.6,40.4 80.6,40.4 100.6,75 80.6,40.4 60.6,75 100.6,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 20.6,75 -19.4,75 5.5,106.3 14.4,67.3 5.5,106.3 41.5,88.9 5.5,71.6 41.5,88.9 32.6,49.9 7.7,81.2 32.6,49.9 -7.4,49.9 17.6,81.2 -7.4,49.9 -16.3,88.9 19.8,71.6 -16.3,88.9 19.8,106.3 10.9,67.3 19.8,106.3 44.7,75 4.7,75" />'
#
# <g transform="rotate(-90.0,4.7,75.0) translate(4.7, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise 5
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
from jupyturtle import *
from jupyturtle import make_turtle

# %%
# Solution goes here
def arc(radius, angle):
    steps = 30
    step_angle = angle / steps
    step_length = 2 * 3.14 * radius * (angle / 360) / steps
    
    for i in range(steps):
        forward(step_length)
        left(step_angle)

# %%
# Solution goes here
def petal(radius, angle):
    arc(radius, angle)
    left(180 - angle)
    arc(radius, angle)
    left(180 - angle)

# %%
def flower(n, radius, angle):
    for i in range(n):
        petal(radius, angle)
        left(360 / n)

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
turtle = make_turtle()

jump(-60)
n = 7
radius = 60
angle = 60
flower(n, radius, angle)

jump(120)
n = 9
radius = 40
angle = 85
flower(n, radius, angle)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 90,75 92.1,75 94.2,74.9 96.3,74.8 98.4,74.6 100.4,74.3 102.5,73.9 104.5,73.5 106.6,73 108.6,72.4 110.6,71.7 112.5,71 114.5,70.2 116.4,69.4 118.3,68.5 120.1,67.5 121.9,66.4 123.7,65.3 125.4,64.2 127.1,62.9 128.8,61.6 130.4,60.3 131.9,58.9 133.5,57.4 134.9,55.9 136.3,54.4 137.7,52.8 138.9,51.1 140.2,49.4 141.3,47.7 142.5,45.9 140.4,45.9 138.
.3,64 164.6,65.5 166,66.9 167.5,68.3 169,69.5 170.5,70.7 172.2,71.9 173.9,72.9 175.6,73.8 177.4,74.7 179.2,75.5 181,76.2 182.9,76.8 184.8,77.3 186.8,77.7 188.7,78 190.7,78.2 192.7,78.3 194.6,78.3 196.6,78.3 198.6,78.1 200.5,77.8 202.5,77.4 204.4,77 206.3,76.4 208.2,75.7 210,75 208.1,74.3 206.3,73.7 204.3,73.3 202.4,72.9 200.4,72.6 198.5,72.4 196.5,72.3 194.5,72.2 192.6,72.3 190.6,72.5 188.6,72.8 186.7,73.2 184.8,73.7 182.9,74.3 181,74.9 179.2,75.7 177.4,76.5 175.7,77.5 174,78.5 172.3,79.6 170.7,80.8 169.2,82 167.8,83.3 166.4,84.7 165,86.2 163.8,87.7 162.6,89.3 161.5,91 160.5,92.7 159.6,94.4 161.4,95.1 163.3,95.7 165.3,96.2 167.2,96.6 169.1,96.9 171.1,97.1 173.1,97.2 175.1,97.2 177,97.1 179,96.9 181,96.6 182.9,96.2 184.8,95.8 186.7,95.2 188.6,94.5 190.4,93.8 192.2,92.9 193.9,92 195.6,91 197.3,89.9 198.9,88.7 200.4,87.4 201.8,86.1 203.2,84.7 204.6,83.2 205.8,81.7 207,80.1 208.1,78.4 209.1,76.7 210,75 208.1,75.7 206.3,76.4 204.5,77.3 202.8,78.2 201.1,79.3 199.5,80.4 197.9,81.6 196.4,82.8 194.9,84.2 193.5,85.6 192.2,87.1 191,88.6 189.8,90.2 188.7,91.9 187.7,93.6 186.8,95.3 186,97.1 185.3,99 184.6,100.8 184.1,102.7 183.6,104.6 183.3,106.6 183,108.5 182.8,110.5 182.8,112.5 182.8,114.5 182.9,116.4 183.1,118.4 183.5,120.4 183.9,122.3 185.7,121.6 187.6,120.8 189.3,120 19

# %%
# Solution goes here

# %% [markdown]
# ### Ask a virtual assistant
#
# There are several modules like `jupyturtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a turtle graphics module to draw a circle:
#
# from jupyturtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(delay=0)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %%
# Solution goes here

# %%
# Solution goes here

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
